# %% [markdown]
# # GB Virus C RNA structure as a evidence for sfRNA

# %%
import pandas as pd

# %%
# %cd /drive/13xrrna/work/plotting/paired/positive_start/
# Out:
# /drive/13xrrna/work/plotting/paired/positive_start

# %%
five_prime = pd.read_csv("SRR10917247_1.tsv", sep="\t", names=['position', 'count'])
five_prime = five_prime.sort_values(by=['count'], ascending=False)

# %%
five_prime.head(20)
# Out:
#       position    count
# 8129      8130  15238.0
# 8054      8055   9743.0
# 8294      8295   9387.0
# 8102      8103   8440.0
# 8405      8406   8325.0
# 8219      8220   8293.0
# 8268      8269   8253.0
# 8134      8135   7055.0
# 8072      8073   6923.0
# 8414      8415   6457.0
# 8634      8635   6285.0
# 8036      8037   6234.0
# 8319      8320   5810.0
# 8083      8084   5601.0
# 8106      8107   5289.0
# 8015      8016   5251.0
# 8378      8379   5158.0
# 8339      8340   5157.0
# 6101      6102   5104.0
# 8081      8082   4599.0

# %%
original_depth = pd.read_csv("/drive/13xrrna/work/plotting/original_depth/SRR10917247.tsv", sep="\t", names=["ref",'position', 'depth'])
original_depth = original_depth.sort_values(by=['depth'], ascending=False)

# %%
original_depth
# Out:
#               ref  position   depth
# 8458  NC_001710.1      8459  354400
# 8457  NC_001710.1      8458  354268
# 8455  NC_001710.1      8456  353736
# 8456  NC_001710.1      8457  353697
# 8453  NC_001710.1      8454  351849
# ...           ...       ...     ...
# 62    NC_001710.1        63       0
# 33    NC_001710.1        34       0
# 32    NC_001710.1        33       0
# 56    NC_001710.1        57       0
# 64    NC_001710.1        65       0
#
# [9392 rows x 3 columns]

# %%
original_depth.head(20)
# Out:
#               ref  position   depth
# 8458  NC_001710.1      8459  354400
# 8457  NC_001710.1      8458  354268
# 8455  NC_001710.1      8456  353736
# 8456  NC_001710.1      8457  353697
# 8453  NC_001710.1      8454  351849
# 8460  NC_001710.1      8461  351668
# 8462  NC_001710.1      8463  351618
# 8450  NC_001710.1      8451  351586
# 8451  NC_001710.1      8452  351555
# 8461  NC_001710.1      8462  351506
# 8452  NC_001710.1      8453  351365
# 8463  NC_001710.1      8464  350980
# 8434  NC_001710.1      8435  350196
# 8459  NC_001710.1      8460  350021
# 8446  NC_001710.1      8447  349888
# 8445  NC_001710.1      8446  349876
# 8447  NC_001710.1      8448  349718
# 8432  NC_001710.1      8433  349443
# 8433  NC_001710.1      8434  349155
# 8448  NC_001710.1      8449  349122

# %% [markdown]
# So the 5 prime peaks are all mostly from 8000 to 9000 which is quite interesting

# %% [markdown]
# I am getting this sequence and folding it and then comparing the structures to https://www.microbiologyresearch.org/content/journal/jgv/10.1099/0022-1317-82-4-713

# %% [markdown]
# ![image.png](attachment:12e423ae-c1f7-4597-be27-c2226377766d.png)

# %% [markdown]
# I think the folds do align up with the predicted stem loops from the paper
